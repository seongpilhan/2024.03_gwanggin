# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split # dataset split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score # 평가도구
from sklearn.metrics import confusion_matrix, accuracy_score # model 평가
import pandas as pd
from datetime import datetime

df = pd.read_csv(r'/광진구-인허가-정보.csv', encoding='UTF-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17143 entries, 0 to 17142
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   개방자치단체코드   17143 non-null  int64
#  1   관리번호       17143 non-null  object
#  2   인허가일자      17143 non-null  object
#  3   인허가취소일자    0 non-null      float64
#  4   영업상태코드     17143 non-null  int64
#  5   영업상태명      17143 non-null  object
#  6   상세영업상태코드   17143 non-null  int64
#  7   상세영업상태명    17143 non-null  object
#  8   폐업일자       12877 non-null  object
#  9   휴업시작일자     0 non-null      float64
#  10  휴업종료일자     0 non-null      float64
#  11  재개업일자      0 non-null      float64
#  12  전화번호       12377 non-null  object
#  13  소재지면적      6124 non-null   object
#  14  소재지우편번호    17141 non-null  object
#  15  지번주소       17143 non-null  object
#  16  도로명주소      8973 non-null   object
#  17  도로명우편번호    8872 non-null   float64
#  18  사업장명       17143 non-null  object
# ...

# %%
df['폐업일자']=pd.to_datetime(df['폐업일자'])
df['인허가일자']=pd.to_datetime(df['인허가일자'])
df2[sub] = df['폐업일자'] - df['인허가일자']
print(df2[sub])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b198b5f2ea5a> in <cell line: 1>()
# ----> 1 df['폐업일자']=pd.to_datetime(df['폐업일자'])
#       2 df['인허가일자']=pd.to_datetime(df['인허가일자'])
#       3 df2[sub] = df['폐업일자'] - df['인허가일자']
#       4 print(df2[sub])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044                 result = arg.tz_localize("utc")
#    1045     elif isinstance(arg, ABCSeries):
# -> 1046         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047         if not cache_array.empty:
#    1048             result = arg.map(cache_array)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
df3 = df2[df2['폐업일자'] >= '2021-01-01']
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 543 entries, 1297 to 13016
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   개방자치단체코드   543 non-null    int64
#  1   관리번호       543 non-null    object
#  2   인허가일자      543 non-null    object
#  3   인허가취소일자    0 non-null      float64
#  4   영업상태코드     543 non-null    int64
#  5   영업상태명      543 non-null    object
#  6   상세영업상태코드   543 non-null    int64
#  7   상세영업상태명    543 non-null    object
#  8   폐업일자       543 non-null    object
#  9   휴업시작일자     0 non-null      float64
#  10  휴업종료일자     0 non-null      float64
#  11  재개업일자      0 non-null      float64
#  12  전화번호       223 non-null    object
#  13  소재지면적      543 non-null    object
#  14  소재지우편번호    543 non-null    object
#  15  지번주소       543 non-null    object
#  16  도로명주소      542 non-null    object
#  17  도로명우편번호    535 non-null    float64
#  18  사업장명       543 non-null    object
# ...
